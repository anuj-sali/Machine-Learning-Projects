# %% [markdown]
# ## Part II: Face Detection Using Multi-Task-Cascaded-Convolutional-Networks Via Deep Learning Using Keras And Tensorflow

# %% [markdown]
# Importing mtcnn and matplotlib essentials

# %%
from mtcnn.mtcnn import MTCNN

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib.patches import Rectangle,Circle

# %%
def modified_image(faces):
    for face in faces:
        ax=plt.gca()
        x,y,w,h=face['box']
        rect=Rectangle((x,y),w,h,fill=False,color='blue')
        ax.add_patch(rect)
        for cor in face['keypoints'].values():
            cir=Circle(cor,radius=1,color='red')
            ax.add_patch(cir)
    plt.imshow(pixels)

# %%
pixels=plt.imread('b.jpg')

# %%
plt.imshow(pixels)

# %%
detector=MTCNN()

# %%
faces=detector.detect_faces(pixels)
# Out:
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000021E60AF8C18> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
modified_image(faces)
